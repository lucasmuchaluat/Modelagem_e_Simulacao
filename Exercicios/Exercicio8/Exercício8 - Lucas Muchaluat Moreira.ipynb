# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
import math

def EquacaoDiferencial(listaSolucoes, t):
    
    x=listaSolucoes[0]
    Vx=listaSolucoes[1]
    y=listaSolucoes[2]
    Vy=listaSolucoes[3]
    
    dxdt=Vx
    dVxdt=((-k * ((x**2 + y**2)**(1/2) - L0) * x/(x**2 + y**2)**(1/2)) + ((1/2 * Ca * d * Af * (Vx**2+Vy**2)) * (-y)/(x**2 + y**2)**(1/2)))* 1/m
    dydt=Vy
    dVydt=((k * (((x**2 + y**2)**(1/2) - L0) * (-y)/(x**2 + y**2)**(1/2)) * 1/m) + (((1/2 * Ca * d * Af * (Vx**2+Vy**2)) * x/(x**2 + y**2)**(1/2)) * 1/m) - g)

    return[dxdt,dVxdt,dydt,dVydt]

x0=0.55 #em m
Vx0=0
y0=0 #em m
Vy0=0
CI=[x0,Vx0,y0,Vy0]
lista_tempo=np.arange(0,5,0.01)
d = 1 #em kg/m3
R = 0.1 #em m
Af = math.pi * R**2 # em m2
m = 0.2 #em kg
k = 20 #em N/m
L0 = 0.5 #em m
Ca = 1.5
g=10 #m/s2

Solucao=odeint(EquacaoDiferencial, CI, lista_tempo)

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(Solucao[:,0], Solucao[:,2])
plt.title("Trajetória de um pêndulo extensível com Rar e raio = 0.1m")
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,0])
plt.title("Abscissa do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('x (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,2])
plt.title("Ordenada do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('y (m)')
plt.show()

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
import math

def EquacaoDiferencial(listaSolucoes, t):
    
    x=listaSolucoes[0]
    Vx=listaSolucoes[1]
    y=listaSolucoes[2]
    Vy=listaSolucoes[3]
    
    dxdt=Vx
    dVxdt=(-k * ((x**2 + y**2)**(1/2) - L0) * x/(x**2 + y**2)**(1/2)) * 1/m
    dydt=Vy
    dVydt=((k * (((x**2 + y**2)**(1/2) - L0) * (-y)/(x**2 + y**2)**(1/2)) * 1/m) - g)
    
    return[dxdt,dVxdt,dydt,dVydt]

x0=0.55 #em m
Vx0=0
y0=0 #em m
Vy0=0
CI=[x0,Vx0,y0,Vy0]
lista_tempo=np.arange(0,5,0.01)
d = 1 #em kg/m3
R = 0.1 #em m
Af = math.pi * R**2 # em m2
m = 0.2 #em kg
k = 20 #em N/m
L0 = 0.5 #em m
Ca = 1.5
g=10 #m/s2

Solucao=odeint(EquacaoDiferencial, CI, lista_tempo)

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(Solucao[:,0], Solucao[:,2])
plt.title("Trajetória de um pêndulo extensível sem Rar e raio = 0.1m")
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,0])
plt.title("Abscissa do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('x (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,2])
plt.title("Ordenada do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('y (m)')
plt.show()

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
import math

def EquacaoDiferencial(listaSolucoes, t):
    
    x=listaSolucoes[0]
    Vx=listaSolucoes[1]
    y=listaSolucoes[2]
    Vy=listaSolucoes[3]
    
    dxdt=Vx
    dVxdt=((-k * ((x**2 + y**2)**(1/2) - L0) * x/(x**2 + y**2)**(1/2)) + ((1/2 * Ca * d * Af * (Vx**2+Vy**2)) * (-y)/(x**2 + y**2)**(1/2)))* 1/m
    dydt=Vy
    dVydt=((k * (((x**2 + y**2)**(1/2) - L0) * (-y)/(x**2 + y**2)**(1/2)) * 1/m) + (((1/2 * Ca * d * Af * (Vx**2+Vy**2)) * x/(x**2 + y**2)**(1/2)) * 1/m) - g)
    
    return[dxdt,dVxdt,dydt,dVydt]

x0=0.55 #em m
Vx0=0
y0=0 #em m
Vy0=0
CI=[x0,Vx0,y0,Vy0]
lista_tempo=np.arange(0,5,0.01)
d = 1 #em kg/m3
R = 0.01 #em m
Af = math.pi * R**2 # em m2
m = 0.2 #em kg
k = 20 #em N/m
L0 = 0.5 #em m
Ca = 1.5
g=10 #m/s2

Solucao=odeint(EquacaoDiferencial, CI, lista_tempo)

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(Solucao[:,0], Solucao[:,2])
plt.title("Trajetória de um pêndulo extensível com Rar e raio = 0.01m")
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,0])
plt.title("Abscissa do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('x (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,2])
plt.title("Ordenada do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('y (m)')
plt.show()

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
import math

def EquacaoDiferencial(listaSolucoes, t):
    
    x=listaSolucoes[0]
    Vx=listaSolucoes[1]
    y=listaSolucoes[2]
    Vy=listaSolucoes[3]
    
    dxdt=Vx
    dVxdt=(-k * ((x**2 + y**2)**(1/2) - L0) * x/(x**2 + y**2)**(1/2)) * 1/m
    dydt=Vy
    dVydt=((k * (((x**2 + y**2)**(1/2) - L0) * (-y)/(x**2 + y**2)**(1/2)) * 1/m) - g)
    
    return[dxdt,dVxdt,dydt,dVydt]

x0=0.55 #em m
Vx0=0
y0=0 #em m
Vy0=0
CI=[x0,Vx0,y0,Vy0]
lista_tempo=np.arange(0,5,0.01)
d = 1 #em kg/m3
R = 0.01 #em m
Af = math.pi * R**2 # em m2
m = 0.2 #em kg
k = 20 #em N/m
L0 = 0.5 #em m
Ca = 1.5
g=10 #m/s2

Solucao=odeint(EquacaoDiferencial, CI, lista_tempo)

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(Solucao[:,0], Solucao[:,2])
plt.title("Trajetória de um pêndulo extensível sem Rar e raio = 0.01m")
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,0])
plt.title("Abscissa do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('x (m)')
plt.show()

plt.figure(figsize=(14,6))
plt.grid(True)
plt.plot(lista_tempo, Solucao[:,2])
plt.title("Ordenada do pêndulo acima ao longo do tempo")
plt.xlabel('t (s)')
plt.ylabel('y (m)')
plt.show()
